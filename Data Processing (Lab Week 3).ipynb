# %%
#1)
import numpy as np
import pandas as pd
data=pd.read_csv(r'C:\Users\Abhishek\Downloads\Dataset.csv')

# %%
# Having a look at data.
data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 0     -122.23     37.88             41.0000          880         322
# 1     -122.23     37.88             41.0000          880         322
# 2     -122.22     37.86             21.0000         7099        2401
# 3     -122.25     37.84             52.0001         3104        1157
# 4     -122.26     37.85             52.0000         3503        1504
# 5     -121.65     39.32             40.0000          812         374
# 6     -121.69     39.36             29.0000         2220        1170
# 7     -121.70     39.37             32.0000         1852         911
# 8     -121.70     39.36             46.0000         1210         523
# 9     -121.70     39.36             37.0000         2330        1505
# 10    -121.69     39.36             34.0000          842         635
# 11    -121.74     39.38             27.0000         2596        1100
# 12    -121.80     39.33             30.0000         1019         501
# ...

# %%
# 2) Missing values 
data.isna()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 0       False     False               False        False       False
# 1       False     False               False        False       False
# 2       False     False               False        False       False
# 3       False     False               False        False       False
# 4       False     False               False        False       False
# 5       False     False               False        False       False
# 6       False     False               False        False       False
# 7       False     False               False        False       False
# 8       False     False               False        False       False
# 9       False     False               False        False       False
# 10      False     False               False        False       False
# 11      False     False               False        False       False
# 12      False     False               False        False       False
# ...

# %%
data.isna().sum()
# we can find null values in 11th row and 20th row ocean_proximity,median_income.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# population            0
# median_income         1
# median_house_value    0
# ocean_proximity       1
# dtype: int64

# %%
# 3)  Filling missing values
data.duplicated().sum()
# Out:
# 2

# %%
# to remove duplicate rows
data = data.drop_duplicates()

# %%
data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 0     -122.23     37.88             41.0000          880         322
# 2     -122.22     37.86             21.0000         7099        2401
# 3     -122.25     37.84             52.0001         3104        1157
# 4     -122.26     37.85             52.0000         3503        1504
# 5     -121.65     39.32             40.0000          812         374
# 6     -121.69     39.36             29.0000         2220        1170
# 7     -121.70     39.37             32.0000         1852         911
# 8     -121.70     39.36             46.0000         1210         523
# 9     -121.70     39.36             37.0000         2330        1505
# 10    -121.69     39.36             34.0000          842         635
# 11    -121.74     39.38             27.0000         2596        1100
# 12    -121.80     39.33             30.0000         1019         501
# 13    -120.46     38.15             16.0000         4221        1516
# ...

# %%
#3) Filling missing values
data.at[11, 'ocean_proximity'] = str('INLAND')
data.at[20, 'median_income'] = data['median_income'].median()

# %%
data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 0     -122.23     37.88             41.0000          880         322
# 2     -122.22     37.86             21.0000         7099        2401
# 3     -122.25     37.84             52.0001         3104        1157
# 4     -122.26     37.85             52.0000         3503        1504
# 5     -121.65     39.32             40.0000          812         374
# 6     -121.69     39.36             29.0000         2220        1170
# 7     -121.70     39.37             32.0000         1852         911
# 8     -121.70     39.36             46.0000         1210         523
# 9     -121.70     39.36             37.0000         2330        1505
# 10    -121.69     39.36             34.0000          842         635
# 11    -121.74     39.38             27.0000         2596        1100
# 12    -121.80     39.33             30.0000         1019         501
# 13    -120.46     38.15             16.0000         4221        1516
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           26 non-null     float64
#  1   latitude            26 non-null     float64
#  2   housing_median_age  26 non-null     float64
#  3   total_rooms         26 non-null     int64
#  4   population          26 non-null     int64
#  5   median_income       26 non-null     float64
#  6   median_house_value  26 non-null     int64
#  7   ocean_proximity     26 non-null     object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 2.9+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           26 non-null     float64
#  1   latitude            26 non-null     float64
#  2   housing_median_age  26 non-null     float64
#  3   total_rooms         26 non-null     int64
#  4   population          26 non-null     int64
#  5   median_income       26 non-null     float64
#  6   median_house_value  26 non-null     int64
#  7   ocean_proximity     26 non-null     object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 2.9+ KB

# %%
# using dictionary to convert specific columns
# changing wrong data types
convert_dict = {'total_rooms': float,
                'population': float,
                'median_house_value': float,
               }
data = data.astype(convert_dict)
print(data.dtypes)

# https://www.geeksforgeeks.org/change-data-type-for-one-or-more-columns-in-pandas-dataframe/
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# population            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  population  \
# 0     -122.23     37.88             41.0000        880.0       322.0
# 2     -122.22     37.86             21.0000       7099.0      2401.0
# 3     -122.25     37.84             52.0001       3104.0      1157.0
# 4     -122.26     37.85             52.0000       3503.0      1504.0
# 5     -121.65     39.32             40.0000        812.0       374.0
# 6     -121.69     39.36             29.0000       2220.0      1170.0
# 7     -121.70     39.37             32.0000       1852.0       911.0
# 8     -121.70     39.36             46.0000       1210.0       523.0
# 9     -121.70     39.36             37.0000       2330.0      1505.0
# 10    -121.69     39.36             34.0000        842.0       635.0
# 11    -121.74     39.38             27.0000       2596.0      1100.0
# 12    -121.80     39.33             30.0000       1019.0       501.0
# 13    -120.46     38.15             16.0000       4221.0      1516.0
# ...

# %%
data.to_csv('Cleaned_data.csv')

# %% [markdown]
# # 7)

# %%
data['median_house_value'].median()
# Out:
# 90200.0

# %%
#8
data['median_house_value'].mean()
# Out:
# 174730.76923076922

# %%
#9
print('Range',data['median_house_value'].max()-data['median_house_value'].min())
# Out:
# Range 396600.0

# %% [markdown]
# # 10)

# %%
#10
print('Median Income in USD',data['median_income']*1000)
# Out:
# Median Income in USD 0     8325.2
# 2     8301.4
# 3     3120.0
# 4     3270.5
# 5     2789.1
# 6     2322.4
# 7     1788.5
# 8     1910.0
# 9     2047.4
# 10    1835.5
# 11    2324.3
# 12    2525.9
# 13    2381.6
# 14    2500.0
# 15    2365.4
# 16    2480.5
# 17    2579.5
# 18    1665.4
# 19    2182.9
# 20    2480.5
# 21    2133.6
# 22    2157.9
# 23    2833.3
# 24    3390.6
# 25    2736.1
# 26    2604.2
# Name: median_income, dtype: float64
